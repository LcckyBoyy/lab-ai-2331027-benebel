# %%
import cv2
from ultralytics import YOLO
import time

model = YOLO("yolo12n.pt")

cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Username atau password RTSP salah")
    exit()

prev_time = time.time()

while True:
    success, frame = cap.read()

    if not success or frame is None:
        print("Gagal membaca frame. coba lagi...")
        cap.release()
        time.sleep(1)
        cap = cv2.VideoCapture(0)
        continue

    # Hitung FPS
    current_time = time.time()
    fps = 1 / (current_time - prev_time)
    prev_time = current_time

    # YOLO inference
    results = model(frame)
    annotated_frame = results[0].plot()

    # Tambahkan FPS ke video
    cv2.putText(annotated_frame, f"FPS: {int(fps)}", (10, 60),
                cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 255, 0), 3)

    # Tampilkan hasil
    cv2.imshow("YOLO RTSP CCTV Inference", annotated_frame)

    # Tekan 'q' untuk keluar
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 86.0ms
# Speed: 2.4ms preprocess, 86.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.0ms
# Speed: 2.4ms preprocess, 87.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.4ms
# Speed: 2.3ms preprocess, 86.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 89.3ms
# Speed: 1.9ms preprocess, 89.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.0ms
# Speed: 2.5ms preprocess, 84.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.6ms
# Speed: 1.9ms preprocess, 84.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.2ms
# Speed: 1.6ms preprocess, 85.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 89.0ms
# Speed: 2.3ms preprocess, 89.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 91.2ms
# Speed: 1.9ms preprocess, 91.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.6ms
# Speed: 2.3ms preprocess, 83.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.9ms
# Speed: 1.8ms preprocess, 81.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 92.9ms
# Speed: 2.4ms preprocess, 92.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 80.7ms
# Speed: 1.8ms preprocess, 80.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.0ms
# Speed: 2.4ms preprocess, 90.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.7ms
# Speed: 2.1ms preprocess, 83.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.1ms
# Speed: 2.4ms preprocess, 81.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 31
#      28 prev_time = current_time
#      30 # YOLO inference
# ---> 31 results = model(frame)
#      32 annotated_frame = results[0].plot()
#      34 # Tambahkan FPS ke video
#
# File d:\College\lab-ai\env\Lib\site-packages\ultralytics\engine\model.py:177, in Model.__call__(self, source, stream, **kwargs)
#     149 def __call__(
#     150     self,
#     151     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     152     stream: bool = False,
#     153     **kwargs: Any,
#     154 ) -> list:
#     155     """Alias for the predict method, enabling the model instance to be callable for predictions.
#     156
#     157     This method simplifies the process of making predictions by allowing the model instance to be called directly
#    (...)    175         ...     print(f"Detected {len(r)} objects in image")
#     176     """
# --> 177     return self.predict(source, stream, **kwargs)
#
# File d:\College\lab-ai\env\Lib\site-packages\ultralytics\engine\model.py:535, in Model.predict(self, source, stream, predictor, **kwargs)
#     533 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     534     self.predictor.set_prompts(prompts)
# --> 535 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File d:\College\lab-ai\env\Lib\site-packages\ultralytics\engine\predictor.py:225, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     223     return self.stream_inference(source, model, *args, **kwargs)
#     224 else:
# --> 225     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File d:\College\lab-ai\env\Lib\site-packages\torch\utils\_contextlib.py:38, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      35 try:
#      36     # Issuing `None` to a generator fires it up
#      37     with ctx_factory():
# ---> 38         response = gen.send(None)
#      40     while True:
#      41         try:
#      42             # Forward the response to our caller and get its next request
#
# File d:\College\lab-ai\env\Lib\site-packages\ultralytics\engine\predictor.py:328, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     326 # Inference
#     327 with profilers[1]:
# --> 328     preds = self.inference(im, *args, **kwargs)
#     329     if self.args.embed:
#     330         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File d:\College\lab-ai\env\Lib\site-packages\ultralytics\engine\predictor.py:182, in BasePredictor.inference(self, im, *args, **kwargs)
#     176 """Run inference on a given image using the specified model and arguments."""
#     177 visualize = (
#     178     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     179     if self.args.visualize and (not self.source_type.tensor)
#     180     else False
#     181 )
# --> 182 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File d:\College\lab-ai\env\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File d:\College\lab-ai\env\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File d:\College\lab-ai\env\Lib\site-packages\ultralytics\nn\autobackend.py:658, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     656 # PyTorch
#     657 if self.pt or self.nn_module:
# --> 658     y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     660 # TorchScript
#     661 elif self.jit:
#
# File d:\College\lab-ai\env\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File d:\College\lab-ai\env\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File d:\College\lab-ai\env\Lib\site-packages\ultralytics\nn\tasks.py:137, in BaseModel.forward(self, x, *args, **kwargs)
#     135 if isinstance(x, dict):  # for cases of training and validating while training.
#     136     return self.loss(x, *args, **kwargs)
# --> 137 return self.predict(x, *args, **kwargs)
#
# File d:\College\lab-ai\env\Lib\site-packages\ultralytics\nn\tasks.py:154, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     152 if augment:
#     153     return self._predict_augment(x)
# --> 154 return self._predict_once(x, profile, visualize, embed)
#
# File d:\College\lab-ai\env\Lib\site-packages\ultralytics\nn\tasks.py:176, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     174 if profile:
#     175     self._profile_one_layer(m, x, dt)
# --> 176 x = m(x)  # run
#     177 y.append(x if m.i in self.save else None)  # save output
#     178 if visualize:
#
# File d:\College\lab-ai\env\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File d:\College\lab-ai\env\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File d:\College\lab-ai\env\Lib\site-packages\ultralytics\nn\modules\block.py:1838, in A2C2f.forward(self, x)
#    1829 """Forward pass through A2C2f layer.
#    1830
#    1831 Args:
#    (...)   1835     (torch.Tensor): Output tensor after processing.
#    1836 """
#    1837 y = [self.cv1(x)]
# -> 1838 y.extend(m(y[-1]) for m in self.m)
#    1839 y = self.cv2(torch.cat(y, 1))
#    1840 if self.gamma is not None:
#
# File d:\College\lab-ai\env\Lib\site-packages\ultralytics\nn\modules\block.py:1838, in <genexpr>(.0)
#    1829 """Forward pass through A2C2f layer.
#    1830
#    1831 Args:
#    (...)   1835     (torch.Tensor): Output tensor after processing.
#    1836 """
#    1837 y = [self.cv1(x)]
# -> 1838 y.extend(m(y[-1]) for m in self.m)
#    1839 y = self.cv2(torch.cat(y, 1))
#    1840 if self.gamma is not None:
#
# File d:\College\lab-ai\env\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File d:\College\lab-ai\env\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File d:\College\lab-ai\env\Lib\site-packages\torch\nn\modules\container.py:250, in Sequential.forward(self, input)
#     246 """
#     247 Runs the forward pass.
#     248 """
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File d:\College\lab-ai\env\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File d:\College\lab-ai\env\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File d:\College\lab-ai\env\Lib\site-packages\ultralytics\nn\modules\block.py:1759, in ABlock.forward(self, x)
#    1750 def forward(self, x: torch.Tensor) -> torch.Tensor:
#    1751     """Forward pass through ABlock.
#    1752
#    1753     Args:
#    (...)   1757         (torch.Tensor): Output tensor after area-attention and feed-forward processing.
#    1758     """
# -> 1759     x = x + self.attn(x)
#    1760     return x + self.mlp(x)
#
# File d:\College\lab-ai\env\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File d:\College\lab-ai\env\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File d:\College\lab-ai\env\Lib\site-packages\ultralytics\nn\modules\block.py:1692, in AAttn.forward(self, x)
#    1689     v = v.reshape(B // self.area, N * self.area, C)
#    1690     B, N, _ = x.shape
# -> 1692 x = x.reshape(B, H, W, C).permute(0, 3, 1, 2).contiguous()
#    1693 v = v.reshape(B, H, W, C).permute(0, 3, 1, 2).contiguous()
#    1695 x = x + self.pe(v)
#
# KeyboardInterrupt:
